# %% [markdown]
# <a href="https://colab.research.google.com/github/plaban1981/Hugging_Face_transformers_topics/blob/main/Hugging_Face_Image_to_Text_Pipeline_for_Image_Captioning%2C_Handwriting_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings,logging
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
logging.disable(logging.WARNING)

# %%
! pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.9 MB 4.7 MB/s
# ...
#      |████████████████████████████████| 163 kB 73.1 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 36.1 MB/s
# ...

# %%
from transformers import pipeline

# %% [markdown]
# ## Image Captioning

# %%
caption = pipeline('image-to-text')
# Out:
# Downloading:   0%|          | 0.00/4.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/982M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/236 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/120 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/211 [00:00<?, ?B/s]

# %%
# !wget -O img2text.jpg 'https://cdn.pixabay.com/photo/2022/08/17/15/13/street-7392734_960_720.jpg'

from IPython.display import Image
Image(filename='img2text.jpg')
# Out:
# --2022-10-03 16:01:35--  https://cdn.pixabay.com/photo/2022/08/17/15/13/street-7392734_960_720.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 172.64.150.12, 104.18.37.244, 2606:4700:4400::6812:25f4, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|172.64.150.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 155407 (152K) [image/jpeg]
# Saving to: ‘img2text.jpg’
#
# img2text.jpg        100%[===================>] 151.76K  --.-KB/s    in 0.03s
#
# 2022-10-03 16:01:35 (5.81 MB/s) - ‘img2text.jpg’ saved [155407/155407]

# %%
caption('img2text.jpg')
# Out:
# [{'generated_text': 'a woman riding a motorcycle down a street '}]

# %%
! wget https://images.fineartamerica.com/images-medium-large-5/elephant-in-the-jungle-aberdare-keren-su.jpg
# Out:
# --2022-10-03 16:26:27--  https://images.fineartamerica.com/images-medium-large-5/elephant-in-the-jungle-aberdare-keren-su.jpg
# Resolving images.fineartamerica.com (images.fineartamerica.com)... 13.226.22.99, 13.226.22.125, 13.226.22.6, ...
# Connecting to images.fineartamerica.com (images.fineartamerica.com)|13.226.22.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 211111 (206K) [image/jpeg]
# Saving to: ‘elephant-in-the-jungle-aberdare-keren-su.jpg’
#
# elephant-in-the-jun 100%[===================>] 206.16K  --.-KB/s    in 0.03s
#
# 2022-10-03 16:26:28 (6.26 MB/s) - ‘elephant-in-the-jungle-aberdare-keren-su.jpg’ saved [211111/211111]

# %%
from IPython.display import Image
Image(filename='/content/elephant-in-the-jungle-aberdare-keren-su.jpg')

# %%
caption('/content/elephant-in-the-jungle-aberdare-keren-su.jpg')
# Out:
# [{'generated_text': 'an elephant with a large tusk walking through a grassy area '}]

# %% [markdown]
# ## OCR

# %%
ocr = pipeline('image-to-text', model = "microsoft/trocr-base-handwritten")
# Out:
# Downloading:   0%|          | 0.00/4.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
# !wget -O handwriting.jpg 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSoolxi9yWGAT5SLZShv8vVd0bz47UWRzQC19fDTeE8GmGv_Rn-PCF1pP1rrUx8kOjA4gg&usqp=CAU'
# Out:
# --2022-10-03 16:14:03--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSoolxi9yWGAT5SLZShv8vVd0bz47UWRzQC19fDTeE8GmGv_Rn-PCF1pP1rrUx8kOjA4gg&usqp=CAU
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 209.85.147.113, 209.85.147.101, 209.85.147.102, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|209.85.147.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4324 (4.2K) [image/jpeg]
# Saving to: ‘handwriting.jpg’
#
# handwriting.jpg     100%[===================>]   4.22K  --.-KB/s    in 0s
#
# 2022-10-03 16:14:03 (61.8 MB/s) - ‘handwriting.jpg’ saved [4324/4324]

# %%
from IPython.display import Image
Image(filename='handwriting.jpg')

# %%
ocr('handwriting.jpg')
# Out:
# [{'generated_text': 'Hope you have done it.'}]

# %%
from IPython.display import Image
Image(filename='/content/hnd2.JPG')

# %%
ocr('/content/hnd2.JPG')
# Out:
# [{'generated_text': 'largest http : 11 mcg.und, ie ( files ( datasets ( bbc-full'}]
