# %% [markdown]
# <a href="https://colab.research.google.com/github/plaban1981/Hugging_Face_transformers_topics/blob/main/How_to_use_GPT_Neo_to_Generate_AI_based_Blog_Content.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 39.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 76.8 MB/s eta 0:00:00
# ...

# %%
import transformers
transformers.__version__
# Out:
# '4.26.0'

# %%
from transformers import pipeline
generator = pipeline('text-generation', model ='EleutherAI/gpt-neo-2.7B')

# %%
import gc
gc.collect()
# Out:
# 258

# %%
post = "Write a blogpost on Ai Content genreation using GPT3"
result = generator(post, max_length=300, do_sample=True, temperature=0.9)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %% [markdown]
# * **post** is the string we created earlier. It contains the text we want the model to generate.
# * **max_length** defines how long your output is going to be. For our case, it’s 50 words.
# * **do_sample** is set to true to allow for sampling within our model.
# * **The temperature** is set to 0.9. This is the value used to model the next set of probabilities.

# %%
print(result[0]['generated_text'])
# Out:
# Blogpost on Blockchain in Banking
#
# This post is for you if you are keen to learn more about Blockchain for banking applications. You are welcome to share your thoughts with me on this post so that I can improve it for next time.
#
# We are always looking for new ideas to bring to our website. If you have anything you want to share for us, feel free to connect and write to me.
#
# Hello, everyone!
#
# Thank you to all of you who have written in to tell us about your experiences with blockchain. I hope this has been helpful!
#
# I was very curious about what people are interested in and what their thoughts are on bitcoin, blockchain, security, and more.
#
# I was also interested

# %%
# !pip install aitextgen
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.2/572.2 KB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 KB 37.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.2/517.2 KB 50.6 MB/s eta 0:00:00
# ...
#   Created wheel for aitextgen: filename=aitextgen-0.6.0-py3-none-any.whl size=576010 sha256=11b5223d46ad5292c43ccb9d8b364983b9090ecd58fd93de3b22a70f40fc758c
#   Stored in directory: /root/.cache/pip/wheels/c2/7f/0c/e0f15aaf9920fe4d0a9d56834f9e97ed86d194f7091f6520d7
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116949 sha256=90eb872b3b7a57c1a08049cfcf6220e65816d6fa96661b83184771459b633e5e
# ...

# %%
pip install git+https://github.com/llimllib/aitextgen@fix_tpu_available
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/llimllib/aitextgen (to revision fix_tpu_available) to /tmp/pip-req-build-3a0dpzlm
#   Running command git clone --filter=blob:none --quiet https://github.com/llimllib/aitextgen /tmp/pip-req-build-3a0dpzlm
#   Running command git checkout -b fix_tpu_available --track origin/fix_tpu_available
#   Switched to a new branch 'fix_tpu_available'
#   Branch 'fix_tpu_available' set up to track remote branch 'fix_tpu_available' from 'origin'.
#   Resolved https://github.com/llimllib/aitextgen to commit 20063f766c3840b69ecf503fcd0fc8140178531d
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# ## Aitextgen

# %% [markdown]
# https://stackoverflow.com/questions/74319873/unable-to-import-name-tpu-available-from-pytorch-lightning-utilities

# %%
! pip uninstall -qqy torch torchvision torchtext torchaudio fastai

# %%
! pip install -qq torch==1.11.0 pytorch-lightning==1.7.7 aitextgen==0.6.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.1/708.1 KB 60.2 MB/s eta 0:00:00

# %%
from aitextgen import aitextgen

# %%
ai = aitextgen()
ai.generate(n=1, prompt="The dog", max_length=100)
# Out:
# INFO:aitextgen:Downloading gpt2 model to /aitextgen.
# ...
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.0"
# }
# ...
# loading configuration file generation_config.json from cache at aitextgen/models--gpt2/snapshots/e7da7f221d5bf496a48136c0cd264e630fe9fcc8/generation_config.json
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.0"
# }
#
# INFO:aitextgen:GPT2 loaded with 124M parameters.
# INFO:aitextgen:Using the default GPT-2 Tokenizer.
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.0"
# }
# The dog is still at the care of his owners, but the dog is expected to be free from the attack.
#
# The dog, which was born with cerebral palsy, has since been transferred to a hospital in South Africa.
#
# ...

# %%
ai = aitextgen(model="EleutherAI/gpt-neo-125M",to_gpu=True)
# Out:
# INFO:aitextgen:Loading EleutherAI/gpt-neo-125M model from /aitextgen.
# ...
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.0"
# }
#
# INFO:aitextgen:Using the tokenizer for EleutherAI/gpt-neo-125M.
# ...
# loading file vocab.json from cache at aitextgen/models--EleutherAI--gpt-neo-125M/snapshots/b983397156c0991016feccfbcbe1fe2746d47b29/vocab.json
# loading file merges.txt from cache at aitextgen/models--EleutherAI--gpt-neo-125M/snapshots/b983397156c0991016feccfbcbe1fe2746d47b29/merges.txt
# loading file tokenizer.json from cache at None
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at aitextgen/models--EleutherAI--gpt-neo-125M/snapshots/b983397156c0991016feccfbcbe1fe2746d47b29/special_tokens_map.json
# ...

# %%
text = ai.generate(n=1, prompt="The adverse effects of pollution on agriculture",max_length=100)
# Out:
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.0"
# }
# The adverse effects of pollution on agriculture, tourism, and other industries have been documented. In addition, the adverse effects of heavy metals on human health and animal and plant health have been studied. The mechanisms of these adverse effects are not completely understood. Furthermore, there are various studies on the effect of heavy metal pollution on human health and reproductive and health problems. In this review, we will provide a summary of the evidence for the effects of heavy metal pollution on human health and reproductive and health.
